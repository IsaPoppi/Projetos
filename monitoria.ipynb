# %% [markdown]
# # **Introdução à Análise de Dados com Python**
#
# Neste notebook, exploraremos um conjunto de dados de títulos de empregos, disponível no Kaggle.
# A análise de dados é fundamental para extrair insights significativos que podem ajudar nas tomadas de decisão dentro das organizações. Usaremos o Python, uma das ferramentas mais poderosas e populares na análise de dados
# devido à sua simplicidade e à vasta biblioteca de recursos disponíveis.

# %% [markdown]
# **Passo a Passo:**
#
# base de dados retirada do kaggle:https://www.kaggle.com/datasets/thedevastator/predicting-job-titles-from-resumes

# %% [markdown]
# 1-Carregar os Dados:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Carregar os dados do arquivo CSV
df = pd.read_csv('/content/jobss.csv')

# Exibir as primeiras linhas do DataFrame
print("Primeiras linhas do DataFrame:")
display(df.head(20))
# Out:
# Primeiras linhas do DataFrame:
#                                             Job Title  Unnamed: 1  \
# 0                               Digital Media Planner         NaN
# 1                            Online Bidding Executive         NaN
# 2    Trainee Research/ Research Executive- Hi- Tec...         NaN
# 3                                   Technical Support         NaN
# 4                   Software Test Engineer -hyderabad         NaN
# 5              Opening For Adobe Analytics Specialist         NaN
# 6      Sales- Fresher-for Leading Property Consultant         NaN
# 7    Opportunity For Azure Devops Architect For Hy...         NaN
# 8                                           BDE- PUNE         NaN
# 9                  Technical Support/ Product Support         NaN
# 10                    Executive Assistant To Chairman         NaN
# 11                                      SEO Executive         NaN
# 12                               Workflow Coordinator         NaN
# 13                                        Oracle IDAM         NaN
# 14   Looking Facebook /social Media Manager For ou...         NaN
# 15         Wanted Engineering Fresher For MNC Chennai         NaN
# 16                             Tooling &amp; Sampling         NaN
# 17                                    Account Manager         NaN
# 18                                  Magento Developer         NaN
# 19   Looking For Trained Freshers in MS Dynamics C...         NaN
#
#    Job Experience Required                                         Key Skills  \
# 0               5 - 10 yrs                      Media Planning| Digital Media
# 1                2 - 5 yrs   pre sales| closing| software knowledge| clien...
# 2                0 - 1 yrs   Computer science| Fabrication| Quality check|...
# 3                0 - 5 yrs                                  Technical Support
# 4                2 - 5 yrs   manual testing| test engineering| test cases|...
# 5                5 - 7 yrs   adobe experience manager| digital| digital ma...
# 6                0 - 0 yrs   channel partners| real estate| negotiation| p...
# 7               9 - 14 yrs   TFS| Azure| Git| VSTS| Docker| DynaTrace| Spl...
# 8                2 - 7 yrs                                                Bde
# 9                1 - 5 yrs   technical support| support services| applicat...
# 10              5 - 10 yrs                 secretary| executive assistant| ea
# 11               1 - 6 yrs   website| web analytics| xml| link building| g...
# 12               2 - 7 yrs   operations| workflow| tat| monitoring| mts| e...
# 13             3 - 7 Years                                Oracle IDAM|OIM|OAM
# 14               2 - 4 yrs   digital marketing| seo| social media marketin...
# 15               0 - 1 yrs   instrumentation engineering| electrical engin...
# 16               2 - 7 yrs   Help Desk| Customer Service| customer relatio...
# 17               3 - 7 yrs   Report Generation| Policies| analytical| proc...
# 18               2 - 7 yrs   Copyright| Email| jQuery| XML| Javascript| Ca...
# 19               0 - 3 yrs   C#| MS Dynamics CRM| Microsoft Dynamics| ms d...
#
#                                  Role Category  \
# 0                                  Advertising
# 1                                 Retail Sales
# 2                                          R&D
# 3   Admin/Maintenance/Security/Datawarehousing
# 4                         Programming & Design
# 5                         Programming & Design
# 6                                 Retail Sales
# 7                         Programming & Design
# 8                          Institutional Sales
# 9                                        Voice
# 10      Corporate Planning/Consulting/Strategy
# 11  Admin/Maintenance/Security/Datawarehousing
# 12                                  Operations
# 13                        Programming & Design
# 14                    Online/Digital Marketing
# 15                                         NaN
# 16                          Engineering Design
# 17                                    Accounts
# 18                        Programming & Design
# 19                        Programming & Design
#
#                                Location  \
# 0                                Mumbai
# 1                             Pune,Pune
# 2                               Gurgaon
# 3                                Mumbai
# 4                             Hyderabad
# 5                                  Pune
# 6                             Bengaluru
# 7                             Hyderabad
# 8                                  Pune
# 9                             Bengaluru
# 10                               Mumbai
# 11      Noida,Delhi,Noida/Greater Noida
# 12                          Delhi,Delhi
# 13  Bengaluru,Hyderabad,Kolkata,Chennai
# 14                              Gurgaon
# 15                              Chennai
# 16                            Faridabad
# 17                               Mumbai
# 18                            Ahmedabad
# 19                            Hyderabad
#
#                                       Functional Area  \
# 0   Marketing , Advertising , MR , PR , Media Plan...
# 1               Sales , Retail , Business Development
# 2                            Engineering Design , R&D
# 3   IT Software - Application Programming , Mainte...
# 4                          IT Software - QA & Testing
# 5   IT Software - Application Programming , Mainte...
# 6               Sales , Retail , Business Development
# 7   IT Software - Application Programming , Mainte...
# 8               Sales , Retail , Business Development
# 9   ITES , BPO , KPO , LPO , Customer Service , Op...
# 10  Strategy , Management Consulting , Corporate P...
# 11    IT Software - eCommerce , Internet Technologies
# 12  ITES , BPO , KPO , LPO , Customer Service , Op...
# 13  IT Software - Application Programming , Mainte...
# 14  Marketing , Advertising , MR , PR , Media Plan...
# 15                                              Other
# 16                           Engineering Design , R&D
# 17  Accounts , Finance , Tax , Company Secretary ,...
# 18    IT Software - eCommerce , Internet Technologies
# 19  IT Software - Application Programming , Mainte...
#
#                                           Industry  \
# 0            Advertising, PR, MR, Event Management
# 1                   IT-Software, Software Services
# 2                            Recruitment, Staffing
# 3                   IT-Software, Software Services
# 4                   IT-Software, Software Services
# 5                   IT-Software, Software Services
# 6                            Real Estate, Property
# 7                   IT-Software, Software Services
# 8                   IT-Software, Software Services
# 9                   IT-Software, Software Services
# 10  Courier, Transportation, Freight , Warehousing
# 11                  IT-Software, Software Services
# 12                          BPO, Call Centre, ITeS
# 13                 IT-Software / Software Services
# 14           Advertising, PR, MR, Event Management
# 15                                           Other
# 16            Industrial Products, Heavy Machinery
# 17                  IT-Software, Software Services
# 18                 Textiles, Garments, Accessories
# 19                  IT-Software, Software Services
#
#                                        Role  Longitude   Latitude   sal
# 0          Media Planning Executive/Manager  72.877393  19.075990  3855
# 1                   Sales Executive/Officer  73.854454  18.521428  2639
# 2                             R&D Executive  77.002700  28.428262  2156
# 3                Technical Support Engineer  72.877393  19.075990  4059
# 4                          Testing Engineer  78.474061  17.360589  5347
# 5                            System Analyst  73.854454  18.521428  4838
# 6                   Sales Executive/Officer  77.590082  12.976794  2585
# 7                       Technical Architect  78.474061  17.360589  3914
# 8                   Sales Executive/Officer  73.854454  18.521428  2111
# 9   Associate/Senior Associate -(Technical)  77.590082  12.976794  2359
# 10      Corporate Planning/Strategy Manager  72.877393  19.075990  5569
# 11                                Webmaster  77.554550  28.390018  2167
# 12                     Process Flow Analyst  77.221939  28.651718  2063
# 13                       Software Developer        NaN        NaN  3239
# 14           Social Media Marketing Manager  77.002700  28.428262  6979
# 15                                    Other  80.270186  13.083694  1513
# 16                   Senior Design Engineer  77.310556  28.403148  6622
# 17                         Accounts Manager  72.877393  19.075990  5324
# 18                       Software Developer  72.579707  23.021624  6891
# 19                       Software Developer  78.474061  17.360589  6493

# %% [markdown]
# **2-Exploração inicial**

# %%
# Exibir informações gerais do DataFrame
print("\nInformações gerais do DataFrame:")
print(df.info())
# Out:
# Informações gerais do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Job Title                489 non-null    object
#  1   Unnamed: 1               0 non-null      float64
#  2   Job Experience Required  500 non-null    object
#  3   Key Skills               500 non-null    object
#  4   Role Category            463 non-null    object
#  5   Location                 489 non-null    object
#  6   Functional Area          489 non-null    object
#  7   Industry                 489 non-null    object
#  8   Role                     486 non-null    object
#  9   Longitude                473 non-null    float64
#  10  Latitude                 473 non-null    float64
#  11  sal                      500 non-null    int64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 47.0+ KB
# None

# %% [markdown]
# **3-Limpeza de Dados**

# %%
# Exibir quantidade de valores ausentes por coluna
print("\nValores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna:
# Job Title                   11
# Unnamed: 1                 500
# Job Experience Required      0
# Key Skills                   0
# Role Category               37
# Location                    11
# Functional Area             11
# Industry                    11
# Role                        14
# Longitude                   27
# Latitude                    27
# sal                          0
# dtype: int64

# %%
# Remover colunas desnecessárias
df = df.drop(columns=['Unnamed: 1', 'Longitude', 'Latitude'])

# Remover as linhas que contêm valores ausentes
df.dropna(inplace=True)


# Verificar novamente valores ausentes após a limpeza
print("\nValores ausentes por coluna após limpeza:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna após limpeza:
# Job Title                  0
# Job Experience Required    0
# Key Skills                 0
# Role Category              0
# Location                   0
# Functional Area            0
# Industry                   0
# Role                       0
# sal                        0
# dtype: int64

# %% [markdown]
# 4-Análise Exploratória de Dados

# %% [markdown]
# Utilidade do Resumo Estatístico:
#
# -Este resumo é extremamente útil para obter uma rápida visão geral da distribuição dos dados numéricos.
#
# -Ajuda a identificar rapidamente problemas potenciais, como outliers extremos ou erros de entrada de dados (por exemplo, um salário extremamente baixo ou alto que não faz sentido).
#
# -Auxilia na compreensão da dispersão dos dados, indicando se estão distribuídos de forma uniforme, se são tendenciosos, ou se há uma grande variabilidade.
#
# Esses insights são fundamentais para decisões subsequentes em análises mais profundas, ajustes de modelos de dados ou mesmo estratégias de negócios e políticas de recursos humanos.

# %%
# Exibir resumo estatístico do DataFrame
print("\nResumo estatístico do DataFrame:")
print(df.describe())
# Out:
# Resumo estatístico do DataFrame:
#                sal
# count   463.000000
# mean   4214.740821
# std    1598.338568
# min    1510.000000
# 25%    2827.000000
# 50%    4199.000000
# 75%    5619.500000
# max    6991.000000

# %% [markdown]
# Utilidade do Código abaixo:
#
# Análise Exploratória de Dados: Este código é particularmente útil na fase inicial de análise de dados, conhecida como Análise Exploratória de Dados (EDA). Ele ajuda os analistas a compreender rapidamente a diversidade e a distribuição das categorias dentro de cada coluna categórica.
#
# Preparação para Limpeza de Dados: Ao identificar os valores únicos em cada coluna, os analistas podem detectar inconsistências, como categorias mal formatadas, erros de digitação ou categorias inesperadas, que podem precisar ser corrigidas ou normalizadas.
#
# Projeto de Modelagem de Dados: Compreender os valores únicos em colunas categóricas também pode informar decisões de modelagem, como a necessidade de transformação desses valores em dados numéricos por meio de técnicas como codificação one-hot ou codificação de etiquetas, especialmente útil em modelagem preditiva e machine learning.
#
# Esse código é uma ferramenta simples, mas poderosa, para obter uma visão rápida das características categóricas de um conjunto de dados, facilitando a tomada de decisões informadas em etapas subsequentes do processo de análise de dados.

# %%
# Exibir valores únicos em colunas categóricas
print("\nValores únicos em colunas categóricas:")
for column in df.select_dtypes(include=['object']).columns:
    print(f"{column}: {df[column].unique()}")
# Out:
# Valores únicos em colunas categóricas:
# Job Title: [' Digital Media Planner' ' Online Bidding Executive'
#  ' Trainee Research/ Research Executive- Hi- Tech Operations'
#  ' Technical Support' ' Software Test Engineer -hyderabad'
#  ' Opening For Adobe Analytics Specialist'
#  ' Sales- Fresher-for Leading Property Consultant'
#  ' Opportunity For Azure Devops Architect For Hyderabad Location'
#  ' BDE- PUNE' ' Technical Support/ Product Support'
#  ' Executive Assistant To Chairman' ' SEO Executive'
#  ' Workflow Coordinator' 'Oracle IDAM'
#  ' Looking Facebook /social Media Manager For our Digital Marketing Ageny'
#  ' Tooling &amp; Sampling' ' Account Manager' ' Magento Developer'
#  ' Looking For Trained Freshers in MS Dynamics CRM- Hyderabad'
#  ' Job Openings Kotak Life/ Max Life/ Aditya Birla Health for Sales Mgr'
#  ' Business Development / Corporate Sales'
#  ' Business Development Manager (BDM)' ' QA Executive'
#  ' Back End Java Developer - Restful Services/soap' ' Product Engineer'
#  ' Opening For Articulate tool Developer - Articulate / Captivate)chennai'
#  ' Urgent Hiring for Area Sales Manager'
#  ' Software Engineer - C++ Development - Ooad/oops'
#  ' Linux Administrator Lead'
#  ' Hiring for Tech Pm/scrum Master for Hyderabad Location'
#  ' US Based Financial Company Looking For Java API Engineers For HYD'
#  ' Strong Partner Ecosystem' ' Wordpress Web Developer'
#  ' Senior Executive- Contract Logistics- Bom WP-A' ' Accounts Manager'
#  ' Technical Sales Executive with fixed pay & lucrative incentives/UK Inb'
#  ' nutanix sme '
#  ' System Architect - 3g/4g Wireless Network Architecture & Migration'
#  'Excellent Opportunity For ” Linux Device Driver ” ,for Hyderabad and Ban'
#  ' Regional Representative' ' Hiring For Record To Report'
#  ' Product & Regional Sales Manager'
#  ' Senior Manager/associate Director - Mandarin'
#  ' ODI Developer/lead ODI Developer - RACI' ' UI Developer'
#  ' Assistant Manager ' ' Android Developer'
#  ' International BPO / Non Voice Process / Rotational Shift / Ahmedabad'
#  ' iOS Developer' ' F&A Black belt - Process Excellence Lead'
#  ' Digital Content Producer For largest Media House' ' Manager Holidays'
#  ' Backend Developer' ' JUNIOR BIG DATA ANALYST IN'
#  ' Oracle DBA Consultant - Data Guard/rac Modules'
#  ' Global HR Operations Analyst' ' Compiler- Support Engineer'
#  ' Key Accounts Manager' ' Head Sales- Coworking Company'
#  ' Clubhouse Manager, Facility Manager,'
#  ' IP DRG / Surgery / ED / Denials Coders'
#  ' Sales Manager - Education Sales' ' HR Associate'
#  ' Manager / Sr Manager - Digital Ad Sales - Ecommerce'
#  ' Architect Junior/ Middle level' ' php developer'
#  ' Openstack Engineer / Openstack Admin with Ceph Storage'
#  ' Sr. Software Engineer' ' Software Engineering- Mentor'
#  ' Application Tester' ' Night Shift - Non Voice / Web Chat - BPO'
#  ' Sales Executive' ' Design Engineer Mechanical' ' Android developer'
#  ' Technical Writer' ' Pro-Engineer , Matlab ,Ansys'
#  ' Business Development Executive - Kolkata'
#  ' Accountant - UK Based Accounting'
#  ' Opportunity For Current Account RM ||bank || Delhi' ' PHP Developer'
#  ' Senior Engineering Maintenance Manager For Knitting and ZLD System'
#  ' Accounting Specialist' ' Manager (Service Operation)'
#  ' DevOps Engineer Intern'
#  ' PHP Developer (wordpress & Woo Commerce/shopify / Magento)'
#  ' Java Developer' ' Sr. Manager- Business Development'
#  ' Test Principal Engineer' ' Graphic Designer'
#  ' Business Development Executive' ' Animation Resident'
#  'Enterprise Business Development Representative' ' Dot Net Developer'
#  ' Urgent Opening for "US Staffing Professionals" - Noida'
#  ' Project Executive/coordinator' ' Sterling OMS Architect'
#  ' Dot net Developer' ' Centreless Grinding Operator '
#  ' PHP Developer Jobs In Gurgaon - Team Lead - PHP' ' Sales Lead'
#  ' Senior Design Engineer - Manufacturing'
#  ' Software Engineer Automation - Industrial Automation Job In Bangalore'
#  ' Looking For Assistant Manager - Healthcare (US Visa is Must)'
#  ' Senior Accounts Executive' ' QA for Voice Process (LE-0097-N1C)'
#  ' Manager/senior Manager- Analytics- Life & Annuities - Insurance Domain'
#  ' Executive Medical Coder' ' Account Assistant'
#  ' Informatica Faculty Job Requirement in Hyderabad'
#  ' SEO Expert/ Digital Marketing Gurgaon' ' Head Engineering'
#  ' PPC Executive'
#  ' Opening For the post of Mr/territory Business Manager in An Pharma'
#  ' Deputy Manager - Program Management'
#  ' Public Relations Manager - Bangalore'
#  " Female Fresher's Counsellor- Gurgaon" ' BE Chemical - Fresher'
#  ' Senior .Net Developer For Leading IT Company in Gurgaon'
#  ' Hiring a Valuation Associate (female Only)'
#  ' Merchandising & Marketing- Professor' ' Medical Transcriber'
#  ' Business Development Manager'
#  ' Looking for a Job Change With a good package'
#  ' Huge Requirement for Customer Care Executive with Fixed Salary'
#  'Assistant Manager – BI&I (data Automation)' ' Field Sales Executive'
#  ' Sr. Manager Sales Capability Building'
#  ' Service Ops Expert - Servc Del | Microland'
#  ' Regional Trainer - Skin for Wellness & Beauty Industry (only Females)'
#  ' Sales Manager' ' Field Support Team-Supervisor' ' Sr. C# Developer'
#  ' Sr Structural Engineer' ' IT Security Head '
#  ' Technical Support Executive' ' Analyst - Business Intelligence'
#  'Nokia WING Circuit Core - SMSC Engineer'
#  ' Assistant Restaurant Manager / Restaurant Manager'
#  ' Digital / Web Artist' ' Web/ GUI Designer'
#  ' Web Designer - Html, CSS, Bootstrap, Photoshop' ' Python Developer'
#  ' Web Designer' ' AVP- FX MO'
#  ' Cluster Sales Head - Tied Channel &amp; Affinity Alliances - Health Insura'
#  ' Head - Project Management'
#  ' Walk- In For Development QA/ Regulatory Affairs'
#  ' Manager Accounts-wazirpur-mba-finance-salary-35k(export House exp)'
#  ' Team Leader- Head Digital Prtnrshp & BD' ' DWH Tester - Manual Testing'
#  ' Quality Assurance Engineer' ' Technical / Functional Skills'
#  ' Software Development / Software Engineer'
#  ' Inbound Phone Banking Voice Process - Leading Bank - Noida'
#  'Java Enterprise Edition' ' Associate Clinical Data Processor' ' CRM'
#  ' Merchandiser' ' SIEM Analyst'
#  ' Hiring ll Azure Devops and Management Lead ll Hyderabad'
#  ' Operation Executive' ' Customer Support Executive'
#  ' Corporate-Day Care Manager.'
#  ' Hiring going on for .US Inbound Tech Support/ Sales'
#  'Deputy Manager- Performance/digital Marketing'
#  ' Technical Lead -(VoIP,Cisco Call Manager)' ' Relationship Manager'
#  ' Technician, Technical Support' ' Consultant'
#  ' Immediate Requirement for Fusion Technical Lead Developer'
#  ' Layout Designer / Web Designer'
#  ' International BPO- Mahindra- Meru- TATA SKY- Paddle Point-pepperfry-hc'
#  ' Asp.net with Angular JS & Html5 - Hyderabad'
#  ' Sales Manager Product and Portfolio'
#  ' Store Head-leading Manufacturing Company'
#  ' BPO Inbound Voice Tech Process - Customer Service Inbound Voice - Appl'
#  ' Java Software Engineer' ' Admin Executive'
#  ' Agm Finance for Automobile Company in Kolkata . Salary:7 Lpa'
#  ' Accounts Manager (male)'
#  ' Opening for French Specialist Accounts Payable'
#  ' Applications Analyst OEE'
#  ' Customer Service Engineer - - ICD Security Solutions'
#  ' Urgently Required Senior PHP Developer(laravel) || Gurgaon '
#  ' Associate Process Consultant' ' Infrastructure management- Lecturer'
#  ' Finance Admin' ' Guest Relations Executive'
#  ' Salesforce System Architect'
#  'System Monitoring Tools & Techniques Professional' ' HR Recruiter'
#  ' Business Development Manager (eCommerce)'
#  ' Java Developer - Spring/ Hibernate'
#  ' Sales And Marketing/Business Development manager'
#  ' Microsoft Developer'
#  ' Customer Service Executive (Adeeba Group) for Tech Support/ Sales'
#  ' Inbound Technical Support With Attractive Salary Package'
#  ' Placement Officer,'
#  ' Walk-in Interviews For Sr.executive - Procurement on 5th July'
#  'Urgent Opening Automation Test Engineer 2-5yrs-bellandur Bangalore'
#  ' Senior TSA Inbound Tech Process'
#  ' Freelance Corporate Trainer on Taleo'
#  ' Senior Java Developer- Urgently Required by Mumbai IT Company'
#  ' Manager Procurement'
#  ' Senior Software Engineer - UI Development - Javascript/angularjs'
#  ' Telle Caller' ' Restaurant Cashier'
#  ' Opening For Dot Net Developer @ Baner, Pune' ' Management Trainee'
#  ' Junior Company Secretary' ' Production Manager'
#  ' Have Confidence to Convince Customer Then Join Adeeba (Inbound Voice)'
#  ' Content Editor' ' Graphics Hardware Engineer' ' Visual Designer'
#  ' ACCOUNTS EXECUTIVES' ' Finance & Accounting Associates'
#  ' DEALER - RETAIL BROKING' ' SENIOR SOFTWARE DEVELOPER (MVC .NET)'
#  ' Client Relationship Partner'
#  ' Sales Manger Opening In An E-commerce Industry- (mumbai, Pune)'
#  ' Sr. Manager- Art in Mumbai || Opportunity @ Client side'
#  ' Hiring for Domestic/ International Processes.contact the HR Asap'
#  ' Manager Learning & Development'
#  ' Urgent Requirement for CCE Telesales for Night Shift.'
#  ' Vancancy for Inbound Tech Sales Executive'
#  ' Infrastructure SSO Architect- Looking For Early Joiners'
#  ' Sr. Architect / Project Position: Sr. Architect / Project'
#  'Nosql (couchdb/redis/bigtable/dynamodb)'
#  ' Immidate Opening for Voice & Accent Trainer @ Vee Technologies'
#  ' Walk- in | Hdfc Life | We are Hiring Freshers:5th till 20th Aug@ Delhi'
#  ' AIT Global India Private Limited is Looking For JAVA Developer.'
#  ' Cloud Engineer Cloud Based IT MNC In Gurgaon , salary 7 - 8 LPA'
#  ' Relationship Manager - Bangalore'
#  ' Territory Sales Manager-Passive Networking-Mumbai/Bangalore/Hyderabad'
#  ' Senior Manager-fundraising'
#  ' Bulk Hiring Travel Sales Consultants US /UK Shifts Call ASAP'
#  ' UI Developer (Frontend Developer)' ' Netsuite Technical Consultant'
#  'Java Full Stack – Technical Lead, Senior Engineer'
#  ' ADM - External Affairs &amp; CSR - Bangalore'
#  ' Immediate Opening Asp.net MVC Developers For Mumbai (worli)'
#  ' Home loan' ' Sr. Resident, General & Laparoscopic Surgery'
#  ' Angular Developer - Fulcrum Digital'
#  ' Devops Engineer - Tools & Automation'
#  ' Great Opportunity To join top MNCs in Kolkata! Grab them While it last'
#  ' QA Functional Testing' ' Sales Engineer'
#  'Software Engineer - Unity Developer'
#  ' Associate Level 1 - Fund Accounting'
#  ' Associate Principal Analyst - Network Security Research'
#  ' Urgent Opening For Field Recruiter ' ' JAVA Developer'
#  ' Urgent Openings For Pharma Freshers'
#  ' Front End Developer - Wordpress/html/css/javascript'
#  'Mechanical Maintenance – Btech / Diploma'
#  'Sr.consultant-power Distribution'
#  ' Chinese, Spanish Language Expert (proofcheck Medical Content),'
#  ' Hiring for Tech Sales_Inbound UK/ US Voice Process'
#  ' SUPPORT Engineers (FEMALE CANDIDATES)'
#  ' MS SQL Developer : 0 - 2 Years (only MALE Candidates)'
#  ' Machine Learning Engineer || Gurgaon/chandigarh Location' ' Nurses'
#  ' Marketing Executive' 'HR Recruiter (volume Hiring)'
#  ' Java Full Stack Developer' ' GM Finance- Export Import Company'
#  ' Content Writer' ' Job Opening for Sm/avp_credit Audit_mumbai'
#  ' iOS Game Developer'
#  ' Hiring: Executive-business Developer(seller Acquisition) On Contract'
#  ' Java/j2ee Application Developer'
#  ' Accepting Application for Intership for Java, PHP, Web Design, Android'
#  ' Automation-Expert-Senior-Automation-Expert'
#  ' Product Manager- Marketing(consumer Durables)'
#  ' Embedded Android Engineer'
#  ' Inbound International BPO Voice Process-US Shift'
#  ' Jr. Support Executives' ' Recruitment Officer '
#  ' Senior Principal Software Engineer'
#  ' Senior Branch Sales & Development Head - Agency - General Insurance'
#  ' Pharma/nutrition Sales Profile Opening with Hexagon Nutrition'
#  ' Urgent job Position For SAP MDG Functional Analyst- All Over India'
#  ' Manager / Asst. Manager - Vendor Development ( Purchase ) - Gurgaon'
#  ' Java with AngularJS and Spring' ' Manager- Admission'
#  ' Sales Head for It Consulting Company in Gurgaon'
#  ' Adeeba Group is Currently hiring for US Inbound Tech Process.'
#  ' Mechanical Engineer Require For Shut Down' ' CARE Specialist'
#  ' Opening For Fresher'
#  ' Technical Support Associate / Technical Sales Associate-Inbound Voice '
#  ' Head of Maintenance'
#  ' Tcs Hiring For Support Analyst - Bigdata(apache Hadoop,aws Certified)'
#  ' Job Opening For Corporate Sales (insurance Broking) Mumbai/ Bangalore'
#  'Spring Boot' ' Sr. Engineer Design (Mechanical)'
#  ' Senior Manager Cost & Program Management'
#  ' Manager Sales Commercial Segment' ' US Tech Process'
#  ' Community Manager,' ' Software Engineer- Mobile Applications - Android'
#  ' Hardware Board Design Engineer' ' Corporate Head - Operations'
#  ' HR Recruitment Executive' ' Software Engineer Android'
#  ' Sales Coordinator' ' Ecommerce Executive' ' Team Lead / Dev Lead'
#  ' Physics Teacher' ' Manager Sales &amp; Marketing' ' Design Engineer'
#  ' VERY Urgent Opening for IT Recruiter & Non IT Recruiter !! Apply NOW '
#  ' Associate' ' Senior .NET Developer'
#  ' Sales Manager : School & Higher Academic Books'
#  ' Supply Chain - Import Export Executive'
#  ' Walk-in Drive for Java Dev/sr. Dev on 29th June at Delhi'
#  ' Hiring for Spring Boot Developer-noida' ' Dynamic CRM Architect'
#  ' SE / SSE - DATA'
#  ' Hiring for Accounts Manager (business Development)- Radio In'
#  'Urgent Openings for O2C' ' ARCHITECTURAL CAD'
#  ' HCL Tech Hiring "physical Design Engineers" for VLSI R&D Division'
#  ' Assistant Manager Purchase' ' Sr. Cloud Developer'
#  ' Hiring for Manager Quality ( Voice and Chat)' ' South Indian Cook,'
#  ' Sharepoint Support Engineer'
#  ' Asst Sales Manager_ API_ Chemical Distribution_ Mumbai'
#  ' Java- Technical Lead- Tavant Technologies - Hyderabad'
#  ' Hiring For Oracle Apps DBA@ Hyderabad'
#  ' Walk in For Pharmacist @ 1mg Technologies || Gurugram Sec 14'
#  ' Agency Manager || Life Insurance ||ahmedabad , Bhopal , Vadodara'
#  ' HR Trainer' ' Project Manager For Civil Work' ' Business Associate'
#  ' Project Support Officer/Administrator'
#  ' Immediate Requirement For Officer - IT @ Vibgyor High, Electronic City'
#  ' Procurement - MDM'
#  " If You're an Experienced in International Tech Sales Then Call Us / In"
#  ' Senior Game Artist' ' Manager (PR)' ' Senior Engineer Project'
#  ' PERL Developer'
#  ' SME Techincal Supervisor_ Red Hat, Fuse, Apache, Camel_magarpatta'
#  ' Wire Industry' ' Manager Brand Marketing'
#  ' Oracle Fusion Apps_manufacturing_any Location' ' VP / Sr.vp Fire'
#  ' Data Science Engineer' 'Executive - Lab Instruments Maintenance'
#  ' Immediate job Opportunity For Printer Engineer in Mumbai - Vashi'
#  ' When you need a Roof you need a job. Come work with us'
#  ' Senior Data Analyst'
#  ' Java / J2EE, Web Services also experienced in AngularJS'
#  ' Senior US IT Recruiter / Senior US Recruiter'
#  ' Service Engineer - Bhiwadi'
#  ' Accounts Executive For 1-2 Years Experience' ' Inbound Tour Manager'
#  ' Swimming Pool Technician' 'Data Science Manager'
#  ' Associate Vice President - Talent Acquisition - Campus Hiring Program'
#  ' Governance & Performance-Performance Management-Professors'
#  ' Manager Sales / Area Manager (tiles, Bath Fitting,paints)'
#  ' Operations - SME / Retail' ' Assistant Manager - HR Operations'
#  ' Sr. Sales / Sales Executive' ' Senior Business Analyst - Sql/python'
#  ' .NET Developer (asp.net, MVC, C#)' ' Head- Land Management.'
#  ' Sr. Business Analyst' ' CNC Machine Operator' ' Executive'
#  ' Inside Sales Executive' ' Customer Care Executive'
#  ' HR - Talent scout specialist' ' Sr. Sales Manager' ' Laundry Executive'
#  ' Accounts executive' ' MBA HR - Experience' ' System Analyst'
#  ' Account Assistance' ' Senior Embedded Engineer'
#  ' Urgent Opening For Asst. Manager-it Infrastructure - Mumbai'
#  ' Sr. Software Engineer Android/Hybrid' ' Principal Engineer-Piping'
#  ' Business Analyst - Structured Finance' 'Solution Architecting'
#  ' Sales / Business Development'
#  ' Medical Coding Job(fresher Ug/pg) Pharm,lifescience,be(biotech&biomed)'
#  ' Assistant Vice President - Stock Broking - Delhi'
#  ' Production Manager in Press Shop & Projection Welding'
#  ' salesfoce Developer +3Years / Mumbai' ' Social Media Executive'
#  ' Business Advisor' ' IT Recruiter, Technical Recruiter'
#  ' SAP PLM Consultant - SAP MM Module'
#  ' Python Manager - IIT/ IIM/ DSE/ ISI'
#  ' Marketing Manager - Activation - Iit/nit'
#  ' Hiring .Net Developers for Hyderabad Location'
#  ' Senior BI Cognos Developer' ' Technical Support Engineer'
#  ' Senior Drupal Developer' ' Pre Sales Executive'
#  ' Head - Sales &amp; Strategy (telematics)'
#  ' Content Writer Required for a Monthly Magazine' ' Sales Engineers'
#  ' Senior Laravel Developer'
#  ' Medical Scribe Chandigarh Mohali Noida No Fees, Salary-26k To 48k'
#  ' Hub-Incharge Bangalore'
#  ' QA - Associate , - Business - Operations - DM' ' Staff Nurse'
#  ' Back Office Executive|data Entry Operators|domestic BPO'
#  ' Sr Equity Advisor - 5 nos' ' Data Scientist - Sql/nosql'
#  ' Hiring For Day Shift Non Voice Sal. Up To 24K' ' React.js Developer'
#  ' Requirement in Private bank for BDE' ' Physics- TGT'
#  ' Urgent Opening - Hp-ux Administrator' ' Support Executive'
#  ' J. Stores - Manager' ' Product Manager' ' Draughtsman'
#  ' Senior Java Tech Lead - Spring Boot/ Data Structure'
#  ' BCOM (hiring for Top4) Internal Audit /compliance Call Vikas'
#  ' ETL Datastage Developer' ' Technical Lead' ' Specialist - DV'
#  ' MES camster/apriso/hydra engineer' ' HR PMO Professional'
#  ' Principal Consultant' ' Cognos TM1 Developer (4 6 years)'
#  ' Smart Web Developer' ' Manager- Compensation and Benefits'
#  ' Civil Architect' ' Reconciliation Executive'
#  ' Oracle Sales Cloud Developer'
#  ' Opening For Sales and Marketing_nariman Point '
#  ' Finance & OPS - Technical Consultant (dynamics Ax/365) @ Bangalore'
#  ' Business Development Manager-digital / Export' ' Website Designer'
#  ' Tech caller hiring a huge number of Executives.']
# Job Experience Required: ['5 - 10 yrs' '2 - 5 yrs' '0 - 1 yrs' '0 - 5 yrs' '5 - 7 yrs' '0 - 0 yrs'
#  '9 - 14 yrs' '2 - 7 yrs' '1 - 5 yrs' '1 - 6 yrs' ' 3 - 7 Years'
#  '2 - 4 yrs' '3 - 7 yrs' '0 - 3 yrs' '0 - 4 yrs' '6 - 8 yrs' '4 - 9 yrs'
#  '3 - 5 yrs' '7 - 12 yrs' '8 - 10 yrs' '3 - 6 yrs' '2 - 3 yrs'
#  '15 - 20 yrs' '10 - 16 yrs' ' 2 - 7 Years' '1 - 4 yrs' '10 - 15 yrs'
#  '5 - 8 yrs' '8 - 13 yrs' '3 - 8 yrs' '6 - 10 yrs' '1 - 3 yrs' '0 - 2 yrs'
#  '1 - 2 yrs' '3 - 4 yrs' '6 - 11 yrs' '4 - 8 yrs' '4 - 7 yrs' '2 - 6 yrs'
#  '12 - 22 yrs' '8 - 12 yrs' '15 - 22 yrs' ' 1 - 3 Years' '10 - 12 yrs'
#  ' 5 - 7 Years' '4 - 5 yrs' ' 5 - 10 Years' '10 - 14 yrs' '4 - 6 yrs'
#  ' 2 - 4 Years' ' 4 - 9 Years' '12 - 17 yrs' '6 - 7 yrs' ' 13 - 15 Years'
#  ' 2 - 5 Years' '10 - 20 yrs' ' 4 - 6 Years' '12 - 18 yrs' ' 6 - 11 Years'
#  ' 3 - 8 Years' ' 0 - 2 Years' ' 4 - 7 Years' '10 - 17 yrs' '7 - 10 yrs'
#  '5 - 9 yrs' '6 - 9 yrs' '12 - 15 yrs' '12 - 16 yrs' '17 - 27 yrs'
#  ' 8 - 12 Years' '20 - 26 yrs' '15 - 18 yrs']
# Key Skills: [' Media Planning| Digital Media'
#  ' pre sales| closing| software knowledge| clients| requirements| negotiating| client| online bidding| good communication| technology'
#  ' Computer science| Fabrication| Quality check| Intellectual property| Electronics| Support services| Research| Management| Human resource management| Research Executive'
#  ' Technical Support'
#  ' manual testing| test engineering| test cases| web testing| web technologies'
#  ' adobe experience manager| digital| digital marketing| adobe analytics| data analytics| aem| adobe| sitecatalyst'
#  ' channel partners| real estate| negotiation| property| Residential Sales'
#  ' TFS| Azure| Git| VSTS| Docker| DynaTrace| Splunk| AWS' ' Bde'
#  ' technical support| support services| application support| communication skills| voice based process| semi voice| semi voice process'
#  ' secretary| executive assistant| ea'
#  ' website| web analytics| xml| link building| google analytics| case studies| seo| social media| tracking| maintaining'
#  ' operations| workflow| tat| monitoring| mts| email'
#  'Oracle IDAM|OIM|OAM'
#  ' digital marketing| seo| social media marketing| content marketing| email marketing| sem| google analytics| campaign management| facebook| media management'
#  ' Help Desk| Customer Service| customer relationship| access controls| Asset Management| Vendor Management'
#  ' Report Generation| Policies| analytical| procedures| Analysts| Data Entry| analytical skills'
#  ' Copyright| Email| jQuery| XML| Javascript| CakePHP| Customer service| Open source| Facebook| CSS3'
#  ' C#| MS Dynamics CRM| Microsoft Dynamics| ms dynamics'
#  ' sales manager| business development manager| relationship manager| brokers| insurance sales| channel sales| direct sale| direct marketing| sales| Marketing Executive| Territory Sales Manager'
#  ' lead generation| business development| corporate sales'
#  ' contract management| closing| it services| relationship building| managed services| selling| market research| business development manager| sales'
#  ' QA Executive'
#  ' Java EE| JMS| Core Java| JUnit| Weblogic| HTML| JPA| JSON| SOAP| SQL'
#  ' Conceptualization| Architecting| Continuous improvement| SIDE| development| Front end| it'
#  ' Articulate Storyline'
#  ' Area Sales Management| Retail Sales| FMCG| Chocolate| confectionary| ASM| Area Sales Manager| area business manager'
#  ' C#| Java| OOP| C++| Multithreading| UML| OOAD| OOPS| .Net| debugging'
#  ' qmail| workflow| nagios| windows server| networking| mysql| monitoring| redhat| maintaining| centos'
#  ' Java| JPA| Hibernate| Project Management| JDBC| Scrum Master| Microservices| Agile| SOAP| Rest'
#  ' Java| java api| Banking| j2ee| API| finance| core java| microservices'
#  ' GIS| ISO 27001| HR| information system| process| ISO 9001| Information security management| GIS software| Management| Edge'
#  'vide'
#  ' Administration| Administrative Support| Contract Logistics| Staff Development| Site Management| Quality Improvement| warehousing| Warehouse Operations'
#  ' filing| tds| service industry| pf| esi| returns| coaching| payroll| invoice| tally'
#  ' Outbound| Antivirus| Technical support| Sales| Spot| Inbound calls| pay| Medical| Comp'
#  ' Troubleshooting| DNS| DHCP| Monitoring| Virtualization| Shell scripting| Python| VMS| Open source| Archiving'
#  ' 4G| 3GPP| 3G| System Architect| LTE| Radio Access Network| PhD| IEEE'
#  'arm processor|c|device drivers|embedded linux|linux kernel|ipc'
#  ' market| presentation| strong analytical skills| english| presentation skills| developing| customer interaction'
#  ' fixed assets| accounts payable| record to report| general accounting| general ledger'
#  ' Team management| Regional sales| Management'
#  ' Commercial Activities| Commercial Sales| Online Sales| Senior Management| Budgeting| Strategy Implementation| Marketing| E - commerce'
#  ' ODI| Matrix'
#  ' javascript| sql| php| php mysql| css| software development| technical| photoshop| mca| ajax| jquery| application| web| design| mysql| html'
#  ' Relationship management| Relationship building| Client relationship| Training| Analytical skills| Process mapping| Standard operating procedures| Agile| Management| Visa processing'
#  ' android| btech| iphone| server| analytical| developing| ios| platforms| objective c| web| xml| design| json| programming| development| c| testing| mobile| xcode| application development| eclipse| application| sdk| applications'
#  ' cca| bpo| csr| international bpo| customer service| outbound process| customer care| tourism| customer support| fresher| voice process| inbound process| cse| bpo fresher| voice support| hotel| travel'
#  ' bca| graphics| application development| b tech| core| b sc| application| b e| ios| publishing| animation'
#  ' Accounting| Continuous Improvement| Process Improvement| Load Balancing| Lean Six Sigma| Black Belt| Training| Green Belt| Process re - engineering| Process Excellence| Business Excellence| OTC'
#  ' Automobile| Digital Content| Content Development| Production| Web Content Writing'
#  ' Tourism| target achievement| negotiation skills| revenue management| Tour Packages'
#  ' PHP| Networking| Data structures| HTTP| JSON| Software design| Computer science| System design| Backend| Ticketing'
#  ' WebLogic| configuration| MySQL| installation| Oracle DBA| troubleshooting| Oracle RAC'
#  ' Service level| Data management| HR Coordinator| Management audit| HR operations| Human resource management'
#  ' Graphics| C++| Windows OS| Linux| high performance computing| Test cases| System software| Gaming| FreeBSD'
#  ' Sales| Team Building| Strategic Leadership| Real Estate| Field Sales| Sales Strategy| Enterprise Business| Go - to - market Strategy| Enterprise sales| Sales Executive Activities| Marketing'
#  ' Facility Management| facility services'
#  ' sds| radiology| CPT| icd - 10| EM| medical coding| coders| surgery| ed'
#  ' Market analysis| Public relations| CV| Relationship building| Market intelligence| Prospecting| Budgeting| Sales process| Branding'
#  ' ERP| MIS| Succession Planning| Reports| Talent Management| Human Resources| HR Policies| Recruitment| Talent Acquisition'
#  ' revenue generation| marketing| ad sales| web technologies'
#  ' co ordination| team management| drafting| loans| online| coordination| quality'
#  ' English| PHP| XML| DOM| SOAP| Com| Web technologies| Written communication| Email| Time'
#  ' cloud| puppet| python| git| KVM| linux| jenkins| openstack| ansible'
#  ' National| Branch| Vice President| J2Ee| Software'
#  ' Mentor| Android| Consulting| Usage| development| software| mobile| it| SIDE| Front end| Web technologies| Coding| web| backend| Open source| programming| Investment'
#  ' Performance Testing| Software Testing| Manual Testing| Quality Testing'
#  ' international bpo| bpo| kpo| web chat| non voice process| e mail| international call center| customer service representative| cse| interpersonal skills| ites| uk shift| customer service| e - commerce| customer care| customer support| bpo fresher'
#  ' Innovative| Aggressive'
#  ' Communication Skills| Detail Engineering| Material Handling| AutoCAD| Detailing| Design Engineering| Microstation| Bid Evaluation'
#  ' design| android| erp| software| mvc| quality'
#  ' Technical Writing| Technical Documentation| Articles| Writing Skills| Product Support'
#  ' Ansys| thermal| MATLAB| System design| Recruitment| MCCB| Electricals'
#  ' Product placement| Market research| Distributor handling| Business Development Executive| Customer service| Customer Service Executive| Secondary sales| Supervision'
#  ' Management accounting| Accounting| VAT| Book Keeping| SAGE| Tax returns'
#  ' Trade| Forex Trading| Forex| fx| Lead Generation| Accounting| Banking| Revenue Generation| Current Account'
#  ' XML| Javascript| PHP| development| css| technical| analytical| software| testing| HTML| tools| Joomla| coding| jQuery| web| MySQL| Wordpress| design| XHTML| debugging| Ajax'
#  ' zld| Engineering Management| knitting'
#  ' Analyst| ERP| Change management| Business objects| Managed services| Business process mapping| Executive management| Data mining| oracle project accounting| Testing'
#  ' ERP| Succession Planning| MIS| Reports| Talent Management| Human Resources| HR Policies| Recruitment| Talent Acquisition'
#  ' Intern| Linux| Windows| Unix| DNS| C++| Perl| IIS| Redhat| HTTP'
#  ' C| Woocommerce| Magento| Wordpress| MySQL| PHP| Shopify| JQuery| Web Development| Ajax'
#  ' CSS| Singleton| XML| Javascript| JDBC| Struts| JSON| HTML| Spring Boot| JQuery'
#  ' Business Development Management| Bd| Marketing| business development| Projects| business development manager| bdm| Tendering| Proposal'
#  ' Ethical Hacking| Certified Ethical Hacker| Networking Protocols| Penetration Testing| Nessus| NMAP| Fortify| Vulnerability Assessment| Appscan| Qualys'
#  ' Graphic designing| Graphics| adobe creative suite| Architecture| MS Office| Business Executive'
#  ' Payment collection| Costing| Business Development Executive| Lead generation| Sales| Vendor| Cost'
#  ' Internship| Digital marketing| Social media| Relationship building| Animation| Creative| Indesign| Business Executive| Presentation skills| Senior'
#  'market penetration|marketing|customer satisfaction|enterprise business|web technologies|business development|strategy|aws|sales'
#  ' jquery| git| microsoft sql server| net asp net| software| testing| ado.net| microsoft| tools| sql| unit tests| database| application| web| design| .net| object oriented programming| support| programming'
#  ' technical recruitment| us staffing| us recruitment| us recruiter| us it staffing| technical recruiter| it recruiter| recruiter| w2| c2c| talent acquisition| recruitment| staffing| sourcing'
#  ' Project Administration| Coordination'
#  ' Order Management system| Sterling Commerce| Sterling| OMS| Sterling Integrator| ecommerce| E - commerce'
#  ' analytical| documentation| web development| algorithms| development| javascript| sql server| jquery| database| web| flex| design| mysql| net'
#  ' NCTVT'
#  ' Drupal| Application programming| MySQL| Wordpress| PHP| CakePHP| Team Leader| MVC| Zend| Software services'
#  ' Outbound| Sales| Project management| Analytical| Sales Lead| Automation tools| Sales process| marketing automation'
#  ' AutoCAD| 3D Modeling| FMEA| Mechanical Engineering| Mechanical Design| SolidWorks'
#  ' Automation Engineer'
#  ' Revenue Cycle Management| US Healthcare| Payment Posting| Medical Billing| Medical Coding| us visa| Team Leading Skills| Healthcare| Denial Management| RCM'
#  ' Voice process| qaqc| Writing| Process operations| Verbal'
#  ' Predictive Modeling| SAS| Data Management| Data Mining| Tableau| Data Analytics| Statistics| Analytics| SQL| Python'
#  ' molecular biology| chemistry| biotechnology| bhms| biology| Physiotherapy| microbiology| nursing| biomedical| Physics| medical coding| biochemistry| pharmacy| Ophthalmology| micro biology| Bioinformatics| zoology| biotech'
#  ' accounts executive| accountant| Stock Management| gst| auditing| Statutory Compliance| accounting| Account Assistant| Bank Reconciliation| tax audit| banking| monthly reports| Payroll| salary processing| income tax| Income Tax Return| taxation'
#  ' Informatica Power Center| Informatica'
#  ' digital marketing| seo specialist| advertising agency| online marketing| seo| seo expert| facebook marketing'
#  ' Validation| Installation| Breakdown Maintenance| Industrial Safety| gmp| Boiler| Design| HVAC| Gensets| Air Compressor| Breakdown| RO| who'
#  ' Forecasting'
#  ' Pay Per Click| Google AdWords| Search Engine Marketing| PPC| SEM| Google Analytics| Website Analysis| Yahoo| Web Analytics| Marketing Initiatives'
#  ' marketing officer| pharma sales| Marketing Representative| marketing executive| pharma marketing| sales officer| sales representative| business development executive| Fresher| trainee| sales executive'
#  ' Project management| PPAP| Automotive| External audit| Conflict resolution| Resource mobilization| PFMEA| Risk management| Project life cycle'
#  ' PR| Public Relations| Media Relations| Social Media| Marketing Communication| corporate communication| media relation| corp comm| Online Media| public relation| Journalism| Advertising| mass communication'
#  ' counselling| couselling| fresher| student counsellor| student counseling'
#  ' asp dot net| .net developer| Dot Net Developer| asp.net| asp . net'
#  ' Secondary Research| Valuation| Finance| Real Estate| Primary| Report Preparation| Business Development| Due Diligence| Financial Modelling'
#  ' Teaching| Educator| Counselor| Mentor| Trainer| Advisor'
#  ' X - Ray| Medical Transcription| Ultrasound| CT Scan'
#  ' cms| javascript| wordpress| drupal| joomla| ajax| cakephp| zend| knowledge| xhtml'
#  ' Sales| Management| Sales management| Educational sales'
#  ' Outbound| Antivirus| Technical support| Technical Support Associate| process| Sales| Inbound calls| US shift| Comp'
#  ' Technical support| English| Comp| Customer Care Executive| Inbound calls| Antivirus| Issue| Software'
#  'C#|Application Development|Senior Level|MS SQL|Visual Basic|Power Bi|MSBI|SSIS|Recruitment|Data Integration'
#  ' Escalation management| Field Sales Executive| Sales achievement| Training| Insurance sales'
#  ' Team management| Salesforce| Usage| Sales| Skill development| Training| Productivity improvement| Training management| Sales budgeting| TSI'
#  ' Networking| Unix| Change management| Scheduling| Publishing| Incident management| VMware| Problem management| Remedy| SIP'
#  ' planning| training| training manager| trainer| faculty'
#  ' Sales| Billing| MS Office| Business reporting| Insurance sales| MIS preparation| Usage| Corporate| Networking| Retail'
#  ' customer support| support service| field support| team| management| supervisor| self motivated| continuous improvement| give| enthusiastic'
#  ' Javascript| SQL| XML| server| css| technical| software| developing| HTML| tracking| database| web| Application development| net| programming| Ajax| development| DOM| solid| data integrity| Stored procedures| Reporting tools| application| applications'
#  ' Senior Design Engineer| Engineering Design| SACS'
#  ' C| Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems'
#  ' Technical Support Executive| Electrical engineering'
#  ' Data analysis| Automation| Google Analytics| Excel| Analytical| Business intelligence| Analytics| Product marketing| SQL| Data extraction'
#  'Detail Design|Juniper|SMSC Engineer|Routing|IP Networking|Network Elements|Network Troubleshooting|High Level Design|Data Center|Switching'
#  ' assistant restaurant manager| restaurant| restaurant manager'
#  ' layout| visualization| digital media| graphic design| html| illustration| tools| part time'
#  ' selling| accounts| events| prospecting| business operations| ideas| coordinating| tracking| closing| maintaining'
#  ' photoshop| illustrator| seo| jquery| fireworks| css3| gui| usability| development| static'
#  ' Photoshop| HTML| Wordpress| CSS3| bootstrap| Web technologies| html5| CSS'
#  ' Python'
#  ' server| multimedia| troubleshooting| graphics| audio| monitoring| javascript| jquery| user interface| css3'
#  ' Senior management| MIS reporting| Building| Training| Management| Risk| Vice President| Focus| Trade| Associate Vice President'
#  ' Sales Head| Tied Channel| Sales| Business Growth| Profitability| Business Operations| New Business| Alliances'
#  ' Project Management'
#  ' QA| Life Sciences| development quality assurance| Life Cycle| Regulatory Affairs| DQA| QMS| Dmf'
#  ' accounting| finance| financial reporting| statutory compliance| gst| vat'
#  ' Data analysis| Consumer research| Management| Head Business Development'
#  ' Testing| Quality| Manual Testing| ETL| BI| DW| Datawarehouse Testing'
#  ' assembly language| Six Sigma| PMP| C| JavaScript| .NET| HTML| Oracle| Python| SQL'
#  ' Product management| Business process| Linkedin| Automation| CV| Email| GIT| Technical| SDLC| Ideas'
#  ' ajax| javascript| php| erp| website| development| software development| module| mca| application development| application| web| programming'
#  ' customer service| customer care| team| communication| bpo| call center| inbound| voice| backend| non voice| telecalling| cse| cro| cce| data entry| back office| voice process| domestic bpo| fresher| trainee| Telemarketing| Outbound| sales| hardware| networking'
#  'Oracle|Core Java|Business process|Outsourcing|Operations|spring integration|J2Ee|Spring framework|JEE|Manager Technology'
#  ' MS Office| Data entry'
#  ' Customer relationship| Automobile| Proposal preparation| CRM strategy| Architecture| Database| Testing'
#  ' Unix| Version control| Prototype| XML| MySQL| PHP| JSON| MVC| Ajax| CSS3'
#  ' Merchandising| Buyer Activities| Follow Ups| Vendor| purchase| vendor development| tracking'
#  ' C#| Azure| Powershell| Script Writing| API| Debugging| Devops| Application Integration'
#  ' operations management| mobilization| Resource Mobilization| general management| interview| Recruitment'
#  ' Customer Support Executive| Customer service| Business Executive| process'
#  ' Staff Training| Day Care| Recruitment'
#  ' process| Spot| Technical support| Night shift| International BPO'
#  'digital marketing|email marketing|adwords|display advertising|digital campaigns|google analytics|sem|seo'
#  ' java| cisco call manager| visa| j2ee| sip| offshore| communication skills'
#  ' Sales| Business Development| Change Management| Mobile| mobiles| handset| mobile handset| Marketing| Relationship Management| Distribution Management| channel management| dealer management| Retailer'
#  ' International Call Center| Technical Support| Maintenance| Communication Skills| PC Hardware| Technician Activities| Social Media| Analytical Ability| Soft Skills| Customer Satisfaction'
#  ' Illustrator| Corel Draw| Photoshop'
#  ' Manual testing| Informatica| microsoft| Process automation| System testing| PDF| Artificial Intelligence| Regression testing| Silicon| Analytics'
#  ' Technical Architecture| Fusion| Oracle Fusion'
#  ' Layout design| Corel Draw| Web designing| Photoshop'
#  ' Bpo Voice| Voice Process| International BPO' ' HTML5| ASP'
#  ' Product training| Sales| Relationship| Banking| Recruitment'
#  ' Customer profitability| Receivable management| Education| Relationship building| Transportation| Service| Monitoring| Key accounts'
#  ' Stores| warehouse| Logistics'
#  ' BPO| Outbound| English| Email| Inbound calls| Customer service| Troubleshooting| Technical support| Recruitment| Comp'
#  ' Linux| Agile| Python| Computer science| Coding| Fixed income| Machine learning| Asset management| JIRA| Financial services'
#  ' English| MS Office| admin executive| Billing| Stock inventory| Writing| Office management| Management| Business Executive| Application'
#  ' Credit Officers| Risk Management| Administration| Report Generation| Analysts| analytical skills'
#  ' Balance Sheet Finalisation| service tax| bank reconciliation| gst| income tax| taxation| financial auditing| finance| tax audit'
#  ' accounts payable| accounting| AP'
#  ' Change management| Healthcare| Analyst| Business Analyst| Social media| Problem management| Software development life cycle| Scheduling| OEE'
#  ' Copyright| Customer Service Representative| CV| Customer service| Security| Troubleshooting| CCTV'
#  ' CSS| jQuery| MySQL| Javascript| HTML| Web Development| Laravel| Codeigniter'
#  ' Networking| Telecom| LAN| WAN| Bss| VPN| Wireless| Telecommunication| Costing| Visio'
#  ' Business communication| Analytical skills| Business objects| Team management| management| Transition management| Trend analysis| Variance analysis| Analytics'
#  ' Usage| PDF| C| Social media| Cash handling| Database| Customer service| Merchandising| Advertising'
#  ' salesforce| salesforce.com| system design| application architecture'
#  'Execution|Project Management|AO engagement|Monitoring Tools|Delivery Management|Stakeholder Management|System Monitoring'
#  ' Recruitment| Hiring| HR| Screening| Interviewing| Staffing'
#  ' bca| cold calling| bidding| academic| customer service| documentation| selling| web development| seo| mba'
#  ' Java| Webservices| Spring| Hibernate| System Design| ESB| SQL| Spring Boot| Javascript'
#  ' Debugging| Troubleshooting| Python| Interpersonal skills| OOPS| Programming| developer'
#  ' Direct sales| Cold calling| English| Networking| Business Development Manager| Customer interfacing| Data collection| Service| Digital marketing| WHO'
#  ' build automation| Entity framework| MVC| microsoft| SQL'
#  ' Technical support| Outbound| Troubleshooting| RecruitmentEnglish| Antivirus| Comp| Customer Service Executive| Domestic BPO'
#  ' Outbound| Medical| Technical support| Technical Support Associate| Email| Sales| US shift| Antivirus| Troubleshooting| Comp'
#  ' HR| Human Resource Management| Placement Coordination| recruitment executive| recruitment officer'
#  ' Strategic Sourcing| procurement| supply chain management| Packaging| Vendor Management'
#  'Test Engineering'
#  ' Outbound| Technical Support Associate| Sales process| process| Senior| Technical| US shift| Technical support| International BPO'
#  ' Corporate Training| corporate trainer| technical trainer'
#  ' java| mongodb| Hibernate| spring| jms'
#  ' Procurement| Supply chain management| Automation| Copyright| Chain| Purchase| Head Operations| Steel| Business Executive'
#  ' software development life cycle| css| html5| ui development| design patterns| svn| software engineering| angularjs| javascript'
#  ' good communication skill| good speeking manners| ability to face strangers| punctual| gopod efficiency'
#  ' Cash Handling| Cashier Activities| Day Book| Cashier| Restaurant| CSAT'
#  ' C#| .Net| Asp.net'
#  ' Excel| Sales| Conflict resolution| Analytical| Management Trainee| Power point presentation| MS Office'
#  ' Manual testing| Eclipse| Coding| Scrum| Enterprise applications| Healthcare| JIRA| Android SDK| test driven development| Business Analyst'
#  ' Production Management| production control| production planning| Production Manager| Planning| Production Support| Organizing'
#  ' Outbound| Medical| Technical support| Technical Support Associate| Email| Technical| US shift| Antivirus| Troubleshooting| Comp'
#  ' Digital media| PHP| Recruitment| Bengali| LMS| Business administration| Content Editor| Journalism| Literature| Administration'
#  ' Graphics| Simulation| Power management| Electronics| Hardware| Research| System analysis| Electricals'
#  ' Motion Graphics| Infographics| Illustrator| animations| infographics| Corel draw| Photoshop| CorelDRAW| Visual Designer'
#  ' Illustrator| Web designing| Photoshop| CSS| Web technologies| XML| Intranet| Business Executive'
#  ' Tally| Retail| Accounts Executive| Retail Executive'
#  ' Financial reporting| Due diligence| Data analysis| Accounting| International finance| Banking'
#  ' NSE| Lead generation| Compliance| Relationship| Equity| Client acquisition| Research| Revenue generation| Monitoring| HNI client handling'
#  ' MySQL| Javascript| UML| server| css| Technical writing| html5| bootstrap| microsoft| Technical support| sql| cloud| ui| web| design| asp.net| mvc| api| architecture| level| Visual Studio| quality| MS SQL| infrastructure| .net| agile| angularjs| aws'
#  ' MIS reporting| Trade| Operational risk| Banking| Relationship| Client relationship| Saving'
#  ' sales strategy| sales management| B2B Sales| corporate sales| institutional sales'
#  ' soa| sql| relationship management| server| software| jquery| service oriented architectures| quality systems| software implementation| computer science| sql server 2008| design'
#  ' Art Director'
#  ' fresher| icse| inbound process| outbound| international bpo| uk process| bcom| communication skills| back office| cbse| web chat| chat process| Aviation| Guest Relations| Public Speaking| PR'
#  ' Outbound| Telesales| Night shift| English| process| Technical| Inbound calls| Service| Printers| Business Executive'
#  ' Outbound| Service| Technical support| process| Inbound calls| Domestic BPO| Bonus| Business Executive| Comp'
#  ' single sign - on| single sign on| IT Infrastructure| SSO'
#  ' layout| coordinating| material selection| ms| mep| photoshop| corel draw| co| monitoring| plumbing'
#  'coding|database design|test cases|analytical|nosql|cassandra'
#  ' accent| auditing| soft skills| training needs| customer service| process compliance'
#  ' Sales| Fresher| Marketing'
#  ' Java EE| Hibernate| Core Java| Software Development| Spring Mvc| Multithreading| OOD| JDBC| Spring Boot| JSF'
#  ' Virtualization| Cloud computing| Server architecture| Windows Troubleshooting| Customer satisfaction| Manager Technology| Deployment| Management'
#  ' business development| sales| sales marketing| marketing executive| sales executive| sales officer| sales manager| area sales manager| territory sales manager| territory manager| area manager| regional manager| regional sales manager| regional business manager'
#  ' Sales| Sale| Networking Sales| It Solution Sales| Structured Cabling| Passive Networking| Data Center| Cable Tray| cabling| Data Center Rack| data - centre rack| LAN| UTP Cables'
#  ' marketing executive| distributors| customer profiling| sales strategy| market research| Business Development| sales executive'
#  ' fundraising| finance'
#  ' worldspan| travel sales consultants| galileo| amadeus| gds'
#  ' Front end| Email| PDF| MIN| UI| phone| Strategic HR| Doc| Consultancy| Recruitment'
#  ' CVS| ERP| Rest| middle east| Technical| Customization| E-commerce| CRM| Open| WHO'
#  'Java|Angular JS|Hibernate|Core Java|Technical Leader|Technical|Javascript|Spring|JQuery|JS framework'
#  ' senior management| ngo| key skills| Corporate Social Responsibility| Govt Liasioning| corporate pr| External Communications'
#  ' Asp.Net MVC| entity framework| API'
#  ' Loans| Direct Sales Associate| Policies| Bfsi| Finance| Sanction| WHO'
#  ' Monitoring| Senior Resident| RAM| DNB| Dmc'
#  ' Angularjs| CSS| Responsive Web Design| Javascript| Bootstrap| HTML| JSON| JQuery| Web Development| Grunt'
#  ' python| open source| database| Automation| java| linux| perl| Monitoring| nosql'
#  ' PR| international bpo| chat process| Aviation| back office| web chat| Guest Relations| Public Speaking| bcom| fresher| inbound process| outbound| uk process| icse| communication skills| cbse'
#  ' QA| Functional testing' ' Sales Engineering'
#  'Design Development|Software Engineering|Lighting|Computer Science|Product Quality|Automation Testing|Asset Management|GUI|Object Oriented Programming|Android'
#  ' NAV calculation| Fund accounting| Automation| Corporate actions| Accounting| Process improvement| Analytical| Reconciliation| Standard operating procedures| Subject Matter Expert'
#  ' Networking| Secondary research| Recruitment| Analyst| Network security| Research| IPS| Advisory| Firewall'
#  ' hiring| HRIS| procurement| HR| sourcing| Recruitment| staffing'
#  ' Computer science| Continuous improvement'
#  ' pharmaceutical| medical| Pharma| medical billing| healthcare'
#  ' CSS| Wordpress| MySQL| Javascript| PHP| HTML| JQuery| SEO| Ajax| Hosting'
#  'mechanical operation|preventive maintenance|mechanical|engineeringbreak down maintenance|mechanical maintenance'
#  ' javascript| html| ajax| jquery| php mysql| smarty| api| analytical| third party| software development life cycle'
#  'Renewable energy|Power distribution|Power sector|Banking|Electricals'
#  ' spanish language expert| chinese| spanish| medical'
#  ' Sales Associate| support| Voice process| Issue| Senior| Technical| Inbound calls| Bonus| US shift| Software'
#  ' MCSE| Database| Support Engineer'
#  ' SSRS| SQL Server| Stored Procedures| SQL Development| MS SQL'
#  ' GIT| Linux| Machine Learning| Python' ' GNM| Business Executive'
#  ' institutions| relationships| marketing executive| customer| customers| implementation| company| site| product'
#  'Recruitment|Volume Hiring|HR|BPO Hiring|Sourcing|Interviewing|Onboarding|Staffing|Orientation|Human Resource Management'
#  ' Java| CSS| Rest| Spring Mvc| Javascript| HTML| JPA| Spring Boot| JQuery| Web Services'
#  ' financial analysis| financial planning| taxation| VP Finance'
#  ' Publishing| SEO| Content management| Social media| Wordpress| Management systems| Research| Brand awareness| Web technologies| Journalism'
#  ' Auditing| Audit Planning| Risk Assessment| Banking| Credit Risk| Credit Policy'
#  ' c++| development| gaming| C| software| HTML| ios| opengl| iphone| design| MySQL| JavaScript'
#  ' business development| e - commerce| sales executive| sales associate| sales officer| sales| field sales| mba fresher| fresher| new product development| channel sales'
#  ' rest| java| sql| oop| angularjs| ui development| oracle'
#  ' Javascript| PHP| HTML| Visualization| jQuery| web| Programming| Commerce| Web designing| Application| Android'
#  ' Process automation| Commodity Markets| Artificial Intelligence| Market intelligence| Machine learning| Corporate| Relationship| Operations| Analytics| Robotics'
#  ' IT Sales| Marketing Campaigns| Social Media| Btl| Marketing Management| Digital Marketing| Dealer Sales| Channel Partners| Communication Skills| Process Flow'
#  ' Android| Troubleshooting| Middleware| Firmware| SOC| Linux kernel| Bluetooth| Computer science| Test scripts| Test strategy'
#  ' Outbound| Antivirus| Technical support| Voice process| Technical Support Executive| US shift| Inbound voice process| Customer Service Executive| Comp| International BPO'
#  ' Sales Executive| Cold calling| market research| customer profiling| sales executive| marketing executive| distributors| Business Development| sales strategy'
#  ' Administration| HR| Recruitment| Recruitment Executive| IR'
#  ' Web development| Analytics| Healthcare| Software design| Monitoring| JIRA| Computer science| Backend| Inside sales| Cloud'
# ...
#  'Housekeeping' 'Pre Sales' 'Investment Banking']
# Location: ['Mumbai' 'Pune,Pune' 'Gurgaon' 'Hyderabad' 'Pune' 'Bengaluru'
#  'Noida,Delhi,Noida/Greater Noida' 'Delhi,Delhi'
#  'Bengaluru,Hyderabad,Kolkata,Chennai' 'Faridabad' 'Ahmedabad'
#  'Bhilai/Bhillai,Bhilwara,Bhopal,Bhubaneshwar,Bikaner,Bilaspur,Bokaro,Chandigarh,Burdwan'
#  'Delhi NCR' 'Chennai' 'Ambala,Gurgaon' 'Gurgaon,Gurgaon' 'Noida'
#  'Kolkata' ' Hyderabad, Bengaluru' 'Gurgaon,Noida' 'Delhi,Gurgaon'
#  'Chandigarh,Chandigarh' 'Chennai,Gurgaon,Bengaluru' 'Bengaluru,Hyderabad'
#  'Chennai,Hyderabad,Trivandrum' 'Delhi NCR,Mumbai'
#  'Ahmedabad,Gandhinagar,Vadodara'
#  'Bengaluru,Hyderabad (1) ,Gurgaon,...More' 'Delhi' 'Chennai,Gurgaon'
#  'Delhi NCR,Noida' 'Delhi (Bhikaji Cama) '
#  'Chennai,Thanjavur,Karur,Salem,Hosur,Coimbatore' 'Delhi NCR,Delhi'
#  'Ahmedabad,Bharuch' 'Delhi NCR,Gurgaon,Delhi' 'Noida,Noida/Greater Noida'
#  ' Mumbai' 'Ghaziabad' 'Ahmedabad,Indore' 'Chandigarh'
#  'Ahmedabad,Ahmedabad' 'Mumbai,Mumbai'
#  'Delhi NCR,Mumbai,Pune,Ahmedabad,Nagpur,Nashik,Gujarat,Maharashtra'
#  'Delhi NCR,Gurgaon' 'Thane,Mumbai,Navi Mumbai' 'Hyderabad,Bengaluru'
#  ' Delhi NCR' 'Bengaluru,Bengaluru / Bangalore'
#  'Delhi NCR,Mumbai,Bengaluru'
#  'Mumbai,Mumbai Suburbs,Navi Mumbai,Thane,Vasai' 'Mumbai,Delhi'
#  ' Bengaluru' 'Navi Mumbai' 'Bengaluru (Bellandur) ' 'Mumbai (Sakinaka) '
#  'Delhi NCR (Shakti Nagar) ' 'Chandigarh,Panchkula' 'Mumbai,Pune'
#  'Gurgaon,Australia' 'Mumbai,Thane' 'Bengaluru (Vasanth nagar) '
#  'Delhi NCR,Agra,Aligarh,Bareilly,Faridabad,Ghaziabad,Meerut,Moradabad,Muzaffarpur'
#  'Bengaluru,Hyderabad,Mumbai' 'Bengaluru,Mumbai,Delhi' ' Hyderabad'
#  'Delhi NCR,Bengaluru' 'Delhi NCR,Chandigarh' ' Gurgaon'
#  'Faridabad,Gurgaon,Mumbai' 'Gurgaon,haryana'
#  'Coimbatore,Raipur,Visakhapatnam,Pune'
#  'Delhi NCR,Mumbai,Pune,Ahmedabad,Gurgaon,Nagpur,Gujarat,Maharashtra,Nashik'
#  'Chennai,Bengaluru' 'Greater Noida' 'Mumbai,Bengaluru'
#  'Delhi NCR,Chandigarh,Mohali' 'Bengaluru,Hyderabad,Chennai,Mumbai'
#  'Bengaluru,Chennai,Hyderabad,Greater Noida' 'Gurgaon,Manesar'
#  'Mumbai,Indore,Pune' 'Bhopal,Ahmedabad,Vadodara'
#  'Ahmedabad (Ellisbridge) ' 'Manesar,Gurgaon,haryana'
#  'Gurgaon,Mumbai,Pune,Cuttack,Chennai,Kanpur,Kolkata,Raipur'
#  'Bengaluru,Pune' 'Mohali,Chandigarh' 'Delhi NCR,Bhiwadi' 'Pune,Gurgaon'
#  'Delhi NCR,Kolkata,Chandigarh' 'Delhi NCR (Sunder Nagar) '
#  'Ahmedabad,Gandhinagar' 'Thane' 'Bengaluru,Chennai'
#  'Chennai Vellore,Salem Erode,Madurai Trichy' 'Delhi NCR,Ghaziabad,Noida'
#  'Chandigarh,Mohali,Panchkula' 'Delhi NCR,Gurgaon,Noida'
#  'Mumbai,Mumbai Suburbs']
# Functional Area: ['Marketing , Advertising , MR , PR , Media Planning'
#  'Sales , Retail , Business Development' 'Engineering Design , R&D'
#  'IT Software - Application Programming , Maintenance'
#  'IT Software - QA & Testing'
#  'ITES , BPO , KPO , LPO , Customer Service , Operations'
#  'Strategy , Management Consulting , Corporate Planning'
#  'IT Software - eCommerce , Internet Technologies'
#  'Accounts , Finance , Tax , Company Secretary , Audit'
#  'Financial Services , Banking , Investments , Insurance'
#  'IT Software - DBA , Datawarehousing'
#  'IT Software - Network Administration , Security'
#  'Purchase / Logistics / Supply Chain'
#  'IT Hardware , Technical Support , Telecom Engineering'
#  'IT Software - Mobile' 'Journalism , Editing , Content'
#  'HR , Recruitment , Administration , IR'
#  'Beauty / Fitness / Spa Services' 'Architecture , Interior Design'
#  'IT Software - Other'
#  'IT Software - Embedded , EDA , VLSI , ASIC , Chip Design'
#  'Hotels , Restaurants' 'Production , Manufacturing , Maintenance'
#  'Design , Creative , User Experience' 'Analytics & Business Intelligence'
#  'Teaching , Education , Training , Counselling'
#  'Medical , Healthcare , R&D , Pharmaceuticals , Biotechnology'
#  'IT Software - System Programming' 'Export , Import , Merchandising'
#  'IT Software - Telecom Software' 'IT Software - ERP , CRM'
#  'CSR & Sustainability' 'Other'
#  'Supply Chain , Logistics , Purchase , Materials'
#  'Site Engineering , Project Management'
#  'Other Employment Type: Full Time, Permanent'
#  'Travel , Tours , Ticketing , Airlines'
#  'Legal , Regulatory , Intellectual Property']
# Industry: ['Advertising, PR, MR, Event Management' 'IT-Software, Software Services'
#  'Recruitment, Staffing' 'Real Estate, Property'
#  'Courier, Transportation, Freight , Warehousing' 'BPO, Call Centre, ITeS'
#  'IT-Software / Software Services' 'Industrial Products, Heavy Machinery'
#  'Textiles, Garments, Accessories' 'Insurance'
#  'Pharma, Biotech, Clinical Research' 'Animation, Gaming'
#  'FMCG, Foods, Beverage' 'Security, Law Enforcement'
#  'Strategy, Management Consulting Firms' 'Internet, Ecommerce'
#  'Education, Teaching, Training' 'Media, Entertainment, Internet'
#  'Aviation, Aerospace, Aeronautical' 'Telcom, ISP' 'Facility Management'
#  'Travel , Hotels , Restaurants , Airlines , Railways'
#  'Oil and Gas, Energy, Power, Infrastructure'
#  'Banking, Financial Services, Broking'
#  'Construction, Engineering, Cement, Metals'
#  'Architecture, Interior Design' 'Medical, Healthcare, Hospitals'
#  'Banking / Financial Services / Broking'
#  'Wellness , Fitness , Sports, Beauty' 'Other' 'Telecom / ISP'
#  'Iron and Steel' 'Fresher, Trainee, Entry Level'
#  'Education / Teaching / Training'
#  'Consumer Electronics, Appliances, Durables'
#  'Automobile, Auto Anciliary, Auto Components'
#  'NGO, Social Services, Regulators, Industry Associations'
#  'Accounting, Finance' 'Semiconductors, Electronics'
#  'Electricals, Switchgears' 'FMCG / Foods / Beverage'
#  'Accounting / Finance' 'BPO / Call Centre / ITES' 'Export, Import'
#  'IT-Hardware & Networking' 'Printing, Packaging' 'Retail, Wholesale'
#  'Chemicals, PetroChemical, Plastic, Rubber' 'Publishing'
#  'KPO, Research, Analytics' 'Pharma / Biotech / Clinical Research'
#  'Strategy / Management Consulting Firms']
# Role: ['Media Planning Executive/Manager' 'Sales Executive/Officer'
#  'R&D Executive' 'Technical Support Engineer' 'Testing Engineer'
#  'System Analyst' 'Technical Architect'
#  'Associate/Senior Associate -(Technical)'
#  'Corporate Planning/Strategy Manager' 'Webmaster' 'Process Flow Analyst'
#  'Software Developer' 'Social Media Marketing Manager'
#  'Senior Design Engineer' 'Accounts Manager' 'Sales Officer'
#  'Sales/Business Development Manager'
#  'Quality Assurance/Quality Control Executive' 'Graphic/Web Designer'
#  'Area Sales Manager' 'System Administrator' 'Project Manager-IT/Software'
#  'Project Lead' 'Logistics Executive' 'Accounts Executive/Accountant'
#  'Associate/Senior Associate -(NonTechnical)' 'Technical Support Manager'
#  'Regional Manager' 'Head / VP/ GM/ National Manager After Sales'
#  'Team Leader -(NonTechnical)' 'Content Developer' 'Business/EDP Analyst'
#  'DBA' 'HR Executive' 'Client Servicing/Key Account Manager'
#  'Head/VP/GM/National Manager -Sales'
#  'Centre Head / Branch Head / Club Manager' 'Project Architect'
#  'Front Office/Guest Relations Executive/Manager' 'Design Engineer'
#  'Technical Writer' 'Engineering Manager' 'Training Manager'
#  'Graphic Designer' 'Client Servicing Executive'
#  'Sales Executive / Officer' 'Recruitment Executive' 'Sales Coordinator'
#  'Solution Architect / Enterprise Architect' 'Workman/Foreman/Technician'
#  'Design Engineer/Manager' 'Technical Lead/Project Lead'
#  'Analytics Manager' 'Trainee'
#  'Search Engine Optimisation /SEO Specialist' 'Financial Analyst'
#  'PPC /Pay Per Click Specialist' 'Medical Representative'
#  'Project Manager-Production/Manufacturing/Maintenance'
#  'Public Relations & Media Relations Manager' 'Fresher' 'Other'
#  'Lecturer/Professor' 'Documentation/Medical Writing'
#  'IT/Networking-Manager' 'Sales Trainer' 'Trainer'
#  'Head/VP/GM-Technology(IT)/CTO' 'Business Analyst' 'Restaurant Manager'
#  'Web Designer' 'Head/VP/GM-Operations' 'Research Scientist'
#  'Merchandiser' 'System Security' 'Team Lead/Technical Lead'
#  'Executive/ Sr Executive - Administration'
#  'DaycareTeacher / Incharge / Attendant' 'Sales / BD Manager'
#  'Logistics Manager' 'Head/VP/GM-Finance/Audit' 'Outside Consultant'
#  'Purchase Executive' 'Purchase/Vendor Development Manager'
#  'Telecalling/Telemarketing Executive' 'Cashier' 'Production Manager'
#  'Visualiser' 'Creative Director' 'Head/VP/GM-Training & Development'
#  'Architect' 'Voice & Accent Trainer' 'Finance/Budgeting Manager'
#  'Outside Technical Consultant' 'CSR Manager' 'Surgeon'
#  'Suguna Group was founded in the year 1984 with the inception of Suguna Foods in poultry sector by first generation entrepreneurs. Suguna is a USD 1.3 billion (INR 9,000 cr) group and leader in Indian protein food/animal farming industry. With an employee footprint of more than 8500, the group is in to poultry, dairy, processed protein food, animal nutrition, healthcare & biologicals. Group companies are Suguna Foods, Suguna Dairy, Globion, Aminovit Srilanka, Suguna Bangladesh and Kenya. Suguna Foods is the largest poultry enterprise in India and it ranks among the top 10 worldwide. The fully integrated operations cover broiler and layer farming, hatcheries, feed mills, processing plants, vaccines and exports. Suguna markets live broiler chicken, value added eggs, ready-to-eat and ready-to-cook chicken products. With the intent to provide consumers with fresh, clean and hygienic packed chicken, Suguna has set up a chain of modern retail outlets in the name of Ã¢â‚¬ËœDaily FresshÃ¢â‚¬â„¢. Suguna Foods pioneered contract farming in poultry industry, and now has presence in 21 states in India. Suguna as a brand is known for its quality products which has been well accepted by the consumers. Suguna Group always believes in energising rural India and providing nutritional security to India and is proud to associate with the mission of improving livelihood of 38,000 farmers'
#  'Proof Reader' 'Nurse' 'Direct Marketing Executive'
#  'Head/VP/GM-CFO/Financial Controller' 'Branch Manager' 'ERP Consultant'
#  'Service/Maintenance Engineer'
#  'Head/VP/GM-Production/Manufacturing/Maintenance' 'Counter Sales'
#  'Physics Teacher' 'Quality Assurance/Quality Control Manager'
#  'Executive/Master Chef' 'Pharmacist/Chemist/Bio Chemist'
#  'Technical / Process Trainer' 'Customer Support Engineer/Technician'
#  'Subject Matter Expert' 'Branch Manager/Regional Manager'
#  'Product/Brand Manager' 'Functional Outside Consultant'
#  'Safety Officer/Manager'
#  'Equipment installation, calibration, validation and maintenance. Maintain the master list for preventive maintenance and calibration of GLP AND NONGLP Instruments Preparing the IQ,OQ,PQ Documentation for new equipment during installation Attend and rectifying the CENTRIFUGE,CO2 INCUBATOR ,HPLC, CENTRIFUGE, CELLCOUNTER, HPLC, ROTAVAPORS, INCUBATORS, WATER PURIFICATION SYSTEMS, FPLC breakdown issues Attend and rectifying the HPLC breakdown issues Coordinating with Vendors, Projects team, Validation team and end-users for installation and qualification (IQ, OQ and PQ) of all the Biologics department equipment. Zero down time maintenance of all laboratory department equipment. Maintaining stock of equipment accessories, spares and consumables as per requirement. To assist, attend and Execute Preventive Maintenance/Breakdown Maintenance for Various Biology and Analytical equipment. Attend breakdown Maintenance calls and Perform routine Preventive Maintenance for Instruments like CENTRIFUGE, CELLCOUNTER, HPLC, ROTAVAPORS, INCUBATORS, WATER PURIFICATION SYSTEMS, HEATING STIRRERS, FLASH CHROMATOGRAPHY SYSTEMS AND VARIOUS BIO-ANALYTICAL INSTRUMENTS IN JUBILANT BIOSYS. Working with Scientists to ensure smooth running of the Equi Salary: Not Disclosed by Recruiter Industry: Pharma / Biotech / Clinical Research Functional Area: Other Employment Type: Full Time, Permanent'
#  'Data Analyst' 'Tour Management Manager/Senior Manager'
#  'Maintenance Engineer'
#  'ZS pioneers in sales force and marketing analytics applying optimization techniques to sales force and marketing investment problems. We have grown significantly and are now recognized global leaders in sales and marketing consulting. A key enabler of our services is leveraging data in delivering client solutions. The data available about customers across Healthcare and multiple industries is getting richer and the problems that our customers are trying to answer continue to evolve. In our endeavor to stay ahead of curve in providing solutions to these evolving complex business problems, ZS has set up a Data Scientist track which has following major focus areas: Research the evolving datasets and newer information sources to understand the possibilities Apply advanced analytical techniques and algorithms to improve current as well as develop cutting edge offerings/solutions Deliver client impact by collaboratively implementing and broad basing these solutions Provide thought leadership by developing the ZS Point of View in the industry The Manager position is the precursor to the Associate Principal and Principal Positions, and therefore part of the ZS leadership ladder. Every Manager leads one or more Spaces, i.e. business units focused either on a specific client, or a specific expertise area. Therefore ZS Data Science Managers are responsible for strong analytical expertise, knowledge and experience of various machine learning algorithms, tools & big data technologies, leveraging this knowledge for innovation, thought leadership, stakeholder relationship management, effectively coaching and responsible for people growth and defining-running-refining their space operating models, guided closely by Principals. Managers leverage their experience to take responsibility for providing analytical solutions across projects, deliver quality work for clients and lead client and ZS-leader relationships from beginning of their tenure. Provide expertise in architecting and implementing analytical solutions for projects Manage projects and assist in managing stakeholder relationships Direct multiple projects simultaneously, honing analytical and project management skills Motivate, coach and serve as a role model for space team members Provide thought leadership and innovation within projects and across practice areas Partner with onshore colleagues to develop new business with existing and new clients Develop and implement specific frameworks for strategy and programs Contribute to ZSs capability building and knowledge creation Coach, mentor, and conduct training programs Play an active role in India office growth related initiatives (e.g. recruiting, training, etc.). Required Candidate profile Managers have 8 - 12 years work experience in industry through consulting work or within an industry leader (a combination of experience is preferred) BE/ B.Tech / BS (stats) from Tier-1 institute would be required. PhD in Computer Science (OR Statistics) / M.Tech / MS from a premier institute would be highly preferred Substantial experience in Machine Learning Knowledge of big data/ advanced analytics concepts and algorithms text mining, social listening, recommender systems, predictive modeling, etc. Knowledge of programming Java/Python/R Exposure to tools/platforms Hadoop eco system and DB systems Agile project planning and project management skills Excellent communication skills In addition, we seek individuals with the following Desire to make a business impact for our clients Leadership experience Personal initiative and strong work ethic Self-motivation and detail orientation Organization & planning skills Communication skills Salary: Not Disclosed by Recruiter Industry: Strategy / Management Consulting Firms Functional Area: Other'
#  'Head/VP/GM-Recruitment' 'HR Manager' 'Head/VP/GM-Regulatory Affairs'
#  'Factory Head' 'Head/VP/GM-HR' 'Housekeeping Executive/Assistant.'
#  'Intern' 'Marketing Manager' 'Pre Sales Consultant' 'Equity Manager'
#  'Telesales/Telemarketing Executive/Officer' 'Draughtsman'
#  'Pay Roll/Compensation Manager']

# %%
df
# Out:
#                                              Job Title  \
# 0                                Digital Media Planner
# 1                             Online Bidding Executive
# 2     Trainee Research/ Research Executive- Hi- Tec...
# 3                                    Technical Support
# 4                    Software Test Engineer -hyderabad
# ..                                                 ...
# 495   Finance & OPS - Technical Consultant (dynamic...
# 496      Business Development Manager-digital / Export
# 497                              Sr. Software Engineer
# 498                                   Website Designer
# 499    Tech caller hiring a huge number of Executives.
#
#     Job Experience Required  \
# 0                5 - 10 yrs
# 1                 2 - 5 yrs
# 2                 0 - 1 yrs
# 3                 0 - 5 yrs
# 4                 2 - 5 yrs
# ..                      ...
# 495               2 - 7 yrs
# 496               5 - 8 yrs
# 497               4 - 9 yrs
# 498               0 - 2 yrs
# 499               2 - 5 yrs
#
#                                             Key Skills  \
# 0                        Media Planning| Digital Media
# 1     pre sales| closing| software knowledge| clien...
# 2     Computer science| Fabrication| Quality check|...
# 3                                    Technical Support
# 4     manual testing| test engineering| test cases|...
# ..                                                 ...
# 495   microsoft dynamics ax| strategy implementatio...
# 496   digital marketing| international sales| inter...
# 497   Unix| PDF| Deployment| Informatica| Oracle| T...
# 498   jQuery| Analytical| Wordpress| Conceptualizat...
# 499   Outbound| Night shift| Recruitment| iPhone| E...
#
#                                   Role Category   Location  \
# 0                                   Advertising     Mumbai
# 1                                  Retail Sales  Pune,Pune
# 2                                           R&D    Gurgaon
# 3    Admin/Maintenance/Security/Datawarehousing     Mumbai
# 4                          Programming & Design  Hyderabad
# ..                                          ...        ...
# 495        System Design/Implementation/ERP/CRM  Bengaluru
# 496                         Institutional Sales      Noida
# 497                        Programming & Design  Hyderabad
# 498                                    Creative    Gurgaon
# 499                                       Voice    Kolkata
#
#                                        Functional Area  \
# 0    Marketing , Advertising , MR , PR , Media Plan...
# 1                Sales , Retail , Business Development
# 2                             Engineering Design , R&D
# 3    IT Software - Application Programming , Mainte...
# 4                           IT Software - QA & Testing
# ..                                                 ...
# 495  IT Software - Application Programming , Mainte...
# 496              Sales , Retail , Business Development
# 497  IT Software - Application Programming , Mainte...
# 498                Design , Creative , User Experience
# 499  ITES , BPO , KPO , LPO , Customer Service , Op...
#
#                                   Industry  \
# 0    Advertising, PR, MR, Event Management
# 1           IT-Software, Software Services
# 2                    Recruitment, Staffing
# 3           IT-Software, Software Services
# 4           IT-Software, Software Services
# ..                                     ...
# 495         IT-Software, Software Services
# 496                    Internet, Ecommerce
# 497         IT-Software, Software Services
# 498         IT-Software, Software Services
# 499         IT-Software, Software Services
#
#                                            Role   sal
# 0              Media Planning Executive/Manager  3855
# 1                       Sales Executive/Officer  2639
# 2                                 R&D Executive  2156
# 3                    Technical Support Engineer  4059
# 4                              Testing Engineer  5347
# ..                                          ...   ...
# 495                              ERP Consultant  4922
# 496          Sales/Business Development Manager  5866
# 497                          Software Developer  1515
# 498                                Web Designer  1946
# 499  Associate/Senior Associate -(NonTechnical)  1511
#
# [463 rows x 9 columns]

# %%
# Calcular a média salarial para cada categoria de "job"
media_salarial_por_job = df.groupby('Job Title')['sal'].mean()

# Criar um DataFrame a partir da série de médias salariais
df_media_salarial = media_salarial_por_job.reset_index()
df_media_salarial.columns = ['Job Title', 'média salarial']

# Exibir o DataFrame resultante
from IPython.display import display
display(df_media_salarial)
# Out:
#                                              Job Title  média salarial
# 0                    .NET Developer (asp.net, MVC, C#)          6630.0
# 1                                  ACCOUNTS EXECUTIVES          5957.0
# 2         ADM - External Affairs &amp; CSR - Bangalore          3893.0
# 3     AIT Global India Private Limited is Looking F...          4770.0
# 4                                    ARCHITECTURAL CAD          3895.0
# ..                                                 ...             ...
# 441                                        Spring Boot          5170.0
# 442                   Sr.consultant-power Distribution          4560.0
# 443  System Monitoring Tools & Techniques Professional          4639.0
# 444  Urgent Opening Automation Test Engineer 2-5yrs...          3991.0
# 445                            Urgent Openings for O2C          2662.0
#
# [446 rows x 2 columns]

# %% [markdown]
# 5-Salvando o novo DF

# %%
# Salvando o DataFrame limpo em um novo CSV
caminho_novo_csv = '/content/jobss_limpo.csv'  # Nome do arquivo CSV para salvar os dados limpos
df.to_csv(caminho_novo_csv, index=False)  # Salvando o DataFrame limpo em um novo arquivo CSV

print("DataFrame limpo salvo com sucesso em:", caminho_novo_csv)
# Out:
# DataFrame limpo salvo com sucesso em: /content/jobss_limpo.csv

# %% [markdown]
# **6- Visualização de dados no PowerBI**
